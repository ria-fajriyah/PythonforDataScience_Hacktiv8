# %% [markdown]
# ## Introduction, Data Types, and Variables

# %% [markdown]
# ### Tipe Data Python
# - Integer
# - Floating
# - String
# - Boolean

# %% [markdown]
# #### Integer

# %%
print(123123123123123123123123123+1)
# Out:
# 123123123123123123123123124

# %%
print(10)
print(type(10))
# Out:
# 10
# <class 'int'>

# %% [markdown]
# #### Float
# - ada digit desimal
# - karakter e atau E

# %%
print(4.2)
print(type(4.2))
print(4.)
print(.2)
print(.4e7)
print(4.2e-4)
# Out:
# 4.2
# <class 'float'>
# 4.0
# 0.2
# 4000000.0
# 0.00042

# %% [markdown]
# #### String
# - menggunakan kutip satu ('') atau dua ("")

# %%
print("Hacktiv8")
# Out:
# Hacktiv8

# %%
nama = 'Nurul Fajriyah Al Maulidiyah'
print(nama)
print(type(nama))
# Out:
# Nurul Fajriyah Al Maulidiyah
# <class 'str'>

# %% [markdown]
# #### Boolean
# - True dan False

# %%
oke = True
print(oke)
print(type(oke))
# Out:
# True
# <class 'bool'>

# %%
oke = False
print(oke)
print(type(oke))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ### Variable Assignment

# %%
a = 1
b = 2
c = 3
d = 4
e = 5

# %%
print(a,b,c,d,e)
# Out:
# 1 2 3 4 5

# %% [markdown]
# #### Aturan Variable Names
# - variable depan bisa menggunakan tanda atau karakter garis bawah (_)
# - variable depan bisa menggunakan huruf besar atau kecil
# - variable depan tidak bisa menggunakan angka

# %% [markdown]
# Standar penamaan suatu variable :
# - Snake Case : fisrt_name
# - Camel Case : firstName
# - Pascal Case : FirstName

# %%
_ = "kosong"
print(_)
# Out:
# kosong

# %%
nama = "ria"
umur = 19
print(nama, umur)
# Out:
# ria 19

# %%
1_angka = False
print(1_angka)
# Out:
#   File "C:\Users\ria\AppData\Local\Temp\ipykernel_19532\3965055718.py", line 1
#     1_angka = False
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ### Operator dan Expression
# ![basic%20arithmetic%20operation.png](attachment:basic%20arithmetic%20operation.png)

# %%
x = 5 
y = 10 

print(x+y)
print(y-x)

print(y/x)
print(y//x)
print(y % x)
print(y ** 2)
# Out:
# 15
# 5
# 2.0
# 2
# 0
# 100

# %% [markdown]
# ### Operator Penugasan
# ![operator%20penugasan.png](attachment:operator%20penugasan.png)

# %%
x = 10 
y = 5 

print(x+y)
y +=x    #  y = y + x 
print(y)
# Out:
# 15
# 15

# %% [markdown]
# ### Comparison Operators
# - membandingkan dua nilai
# - menggunakan operator relasi
# ![comparison%20operators.png](attachment:comparison%20operators.png)

# %%
x = 20 
y = 40 

print(x == y)
# Out:
# False

# %% [markdown]
# ### Operator Logika
# ![operator%20logika.png](attachment:operator%20logika.png)

# %%
a = True
b = False

print(a and b) # false 
print(a or b) # true
# Out:
# False
# True

# %% [markdown]
# ### String Manipulation

# %%
a = "Hai "
b = "Hello "
c = "Hola "

print(a + b + c)
# Out:
# Hai Hello Hola

# %%
hai = "Apakabar"
print(hai * 5)

print("="* 40)

print(hai in 'Apakabar Jakarta?')
# Out:
# ApakabarApakabarApakabarApakabarApakabar
# ========================================
# True

# %% [markdown]
# ### Case Conversion

# %%
x = "Google"

#lower (huruf kecil semua)
print(x.lower())
#Uper (huruf besar semua)
print(x.upper())
# swapcase (huruf kecil jadi besar dan sebaliknya)
print(x.swapcase())

y = "hadapi dengan senyuman"

print(y.capitalize())

print(y.title())
# Out:
# google
# GOOGLE
# gOOGLE
# Hadapi dengan senyuman
# Hadapi Dengan Senyuman

# %% [markdown]
# ### Container
# ![01_container.png](attachment:01_container.png)

# %% [markdown]
# ![05_container.png](attachment:05_container.png)

# %%
names = ["Bowo","Joko","Budi"]
phone_book ={ "Ketut":"08121312121111", "Gunawan": "08121212121121"}

# %% [markdown]
# ### Python List
# menggunakan tanda kurung siku
#
# Karakteristik penting dari List Python adalah sebagai berikut:
# - Lists di siapkan.
# - Lists dapat berisi objek sembarang.
# - Elemen Lists dapat diakses dengan indeks.
# - List dapat masukan ke kedalaman yang bebas.
# - List bisa berubah.
# - List bersifat dinamis.

# %%
names= ['budi','Joko','Jono','Jeky']
print(names)
print(type(names))
# Out:
# ['budi', 'Joko', 'Jono', 'Jeky']
# <class 'list'>

# %%
variabel_sembarang = ['Budi','Joko',100, 50.5, True]
print(variabel_sembarang)
print(type(variabel_sembarang))
# Out:
# ['Budi', 'Joko', 100, 50.5, True]
# <class 'list'>

# %%
variabel_sembarang[0]
# Out:
# 'Budi'

# %% [markdown]
# ![data%20list.png](attachment:data%20list.png)

# %%
data_list = ['foo','bar','baz','qux','quux', 'corge']
print(data_list[5])
print(data_list[-1])
# Out:
# corge
# corge

# %%
data_list = ['foo','bar','baz','qux','quux', 'corge']
print(data_list[0:4])


print(data_list[:4])

print(data_list[0:]) # 0 sampai akhir
# Out:
# ['foo', 'bar', 'baz', 'qux']
# ['foo', 'bar', 'baz', 'qux']
# ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']

# %%
buah = ['apel','mangga','pepaya','jambu']

print('jeruk' in buah) 

print('apel' in buah)
# Out:
# False
# True

# %%
buah.remove('pepaya')
print(buah)
# Out:
# ['apel', 'mangga', 'jambu']

# %%
buah.append("durian")
print(buah)
# Out:
# ['apel', 'mangga', 'jambu', 'durian']

# %%
buah_delete = buah.pop(2)
print(f"{buah_delete} telah di delete")
# Out:
# jambu telah di delete

# %%
buah.sort()

print(buah)
# Out:
# ['apel', 'durian', 'mangga']

# %% [markdown]
# ### Python Tuples
# menggunakan kurung tupup '()' tidak bisa di rubah

# %%
buah_tuple = ('apel', 'durian', 'mangga', 'mangis', 'rambutan')
print(buah_tuple)
print(type(buah_tuple))
# Out:
# ('apel', 'durian', 'mangga', 'mangis', 'rambutan')
# <class 'tuple'>

# %%
buah_tuple[1]
# Out:
# 'durian'

# %%
x1 = x2 = x3 =('satu','dua','tiga')

# %%
print(x1, x2, x3)
# Out:
# ('satu', 'dua', 'tiga') ('satu', 'dua', 'tiga') ('satu', 'dua', 'tiga')

# %%
countdown = 1,2,3, "RUN!!!!" 
print(countdown)
print(type(countdown))
# Out:
# (1, 2, 3, 'RUN!!!!')
# <class 'tuple'>

# %% [markdown]
# ### Python Dictionary
# - {}
# - isi bisa berupa list
# - isi bisa berupa object
# - bisa berubah dan dinamis
# - key dan Value (dapat diakses menggunakan key)
# - key string
# - key dan value di pisahkan menggunakan titik dua ':'
# ![dictionary.png](attachment:dictionary.png)

# %%
MLB_team = {
    'Colorado':'Rockies',
    'Boston':'Red Sox',
    'Minnesota':'Twins',
    'Milwauke':'Brewers',
    'Seatle':'Mariners',
}

# %%
print(MLB_team)
print(type(MLB_team))
# Out:
# {'Colorado': 'Rockies', 'Boston': 'Red Sox', 'Minnesota': 'Twins', 'Milwauke': 'Brewers', 'Seatle': 'Mariners'}
# <class 'dict'>

# %%
print(MLB_team['Boston'])
# Out:
# Red Sox

# %%
person = {}
type(person)
# Out:
# dict

# %%
person['fname'] = "IKetut"
person['lname'] = "Gunawan"
person['age'] = 45 
person['pets'] = ['cats','ant']
person['skill'] = {"programming":['Java','Golang','Python','Solidity'],
                   "database":{"nosql":['MonggoDb','Neo4J'],"rdbms":['Mysql','PostgreSQL','Oracle']}}

# %%
print(person)
# Out:
# {'fname': 'IKetut', 'lname': 'Gunawan', 'age': 45, 'pets': ['cats', 'ant'], 'skill': {'programming': ['Java', 'Golang', 'Python', 'Solidity'], 'database': {'nosql': ['MonggoDb', 'Neo4J'], 'rdbms': ['Mysql', 'PostgreSQL', 'Oracle']}}}

# %%
import json 
print(json.dumps(person, sort_keys=False, indent=4))
# Out:
# {
#     "fname": "IKetut",
#     "lname": "Gunawan",
#     "age": 45,
#     "pets": [
#         "cats",
#         "ant"
#     ],
#     "skill": {
#         "programming": [
#             "Java",
#             "Golang",
#             "Python",
#             "Solidity"
#         ],
#         "database": {
#             "nosql": [
#                 "MonggoDb",
#                 "Neo4J"
#             ],
#             "rdbms": [
#                 "Mysql",
#                 "PostgreSQL",
#                 "Oracle"
#             ]
#         }
#     }
# }

# %% [markdown]
# ### Set

# %%
varx = set("Helloapakabar")
print(varx)
print(type(varx))
# Out:
# {'H', 'r', 'e', 'o', 'k', 'p', 'l', 'a', 'b'}
# <class 'set'>

# %%
set([1,2,3,4])
# Out:
# {1, 2, 3, 4}

# %%
beatles = {"John","Paul","Ringo","Gorge"}
print(type(beatles))
print(beatles)

beatles.remove("John")
beatles.add("Ketut")
print(beatles)

beatles.add("Paul")
print(beatles)
# Out:
# <class 'set'>
# {'John', 'Ringo', 'Paul', 'Gorge'}
# {'Ringo', 'Ketut', 'Paul', 'Gorge'}
# {'Ringo', 'Ketut', 'Paul', 'Gorge'}

# %%
nirvana = {"Kurt","Cris","Dave"}

new_band = beatles | nirvana 
print(new_band)
# Out:
# {'Cris', 'Ringo', 'Gorge', 'Paul', 'Dave', 'Ketut', 'Kurt'}

# %%
word1 = {'A','B','C','D','E','F'}
word2 = {'C','E','A','X','Y','Z'}
